# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Creating a Style
sns.set_style('white')

#Assigning the values for barplot
x=[2001,2002,2003,2004,2005]
y=[10201,12300,14899,900,15095]
plt.plot(x,y)
plt.title('Line Chart')
plt.xlabel("city")
plt.ylabel("Median Income")
plt.show()
